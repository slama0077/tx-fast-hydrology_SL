# %%
import sys, os

sys.path.append(os.path.abspath(".."))

# %%
from tx_fast_hydrology.bmi_KF import BmiKF

KF_model = BmiKF()

# %%
#initialize the file with yaml file
KF_model.initialize("KF.yaml")

# %%
#check the initial datetime
KF_model.get_current_datetime()
# Out:
# Timestamp('2022-08-22 00:00:00+0000', tz='UTC')

# %%
#update the model by one timdelta default to be 15 minutes in the json file
KF_model.update()

# %%
KF_model.model_collection.datetime
# Out:
# Timestamp('2022-08-22 00:15:00+0000', tz='UTC')

# %%
#sorted reach list
KF_model.get_value_ptr("reach_list")
# Out:
# Index(['2416825', '2416826', '2416827', '2416828', '2416829', '2416830',
#        '2416831', '2416908', '2416909', '2416910',
#        ...
#        '2437061', '2437062', '2437063', '2437064', '2437065', '2437066',
#        '2437067', '2437068', '2437069', '2437070'],
#       dtype='object', length=557)

# %%
#discharge associated with sorted reach_list
KF_model.get_value_ptr("discharge")
# Out:
# array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 2.22818072e-02, 6.68454215e-02, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 2.22818072e-02, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 5.07185924e-02,
#        2.17347417e-01, 0.00000000e+00, 9.40118822e-02, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
# ...

# %%
#update by 30 mimnutes
KF_model.update_until(1800)

# %%
KF_model.get_current_datetime()
# Out:
# Timestamp('2022-08-22 00:45:00+0000', tz='UTC')
